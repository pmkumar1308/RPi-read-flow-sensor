# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from datetime import date

# %%
def plot_data(df):   
    max_range = 200
    data = df.to_numpy()
    fig, axs = plt.subplots(4,1, sharex = True, figsize=(15,25))
    st = fig.suptitle("Data plotted on", fontsize="x-large")
    axs[0].plot(data[:,0], data[:,4]*1e6, label = "Integerated mass mg")
#     axs[0].plot(data[:,0], data[:,5]*1e6, label = "GT Mass mg")
    axs[0].plot(data[:,0], data[:,6]*1e6, label = "Desired Mass mg")    
    axs[0].set_xlabel("Time in seconds")
    axs[0].set_ylabel("Mass in mg")
    axs[0].set_title("Integrated mass vs Desired Mass")
    axs[0].legend()

    axs[1].plot(data[:,0], data[:,1], label = "Measured flow Value(l/min)")
    axs[1].plot(data[:,0], data[:,2], label = "Target flow Value(l/min)")
    axs[1].set_xlabel("Time in seconds")
    axs[1].set_ylabel("Volume flow rate in l/min")
    axs[1].set_title("Measured value of the flow rate")
    axs[1].legend()

    axs[2].plot(data[:,0], data[:,3], label = "Pressure in kPa")
    axs[2].set_xlabel("Time in seconds")
    axs[2].set_ylabel("Pressure in kPa")
    axs[2].set_title("Measured pressure")
    axs[2].legend()
    
    axs[3].plot(data[:,0], data[:,7], label = "Set Voltage  in V")
    axs[3].set_xlabel("Time in seconds")
    axs[3].set_ylabel("Set voltage in V")
    axs[3].set_title("Set Voltage")
    axs[3].legend()
    
#     axs[3].plot(data[:,0], data[:,3], label = "Integrated Mass kg")
#     axs[3].set_xlabel("Time in seconds")
#     axs[3].set_ylabel("Mass in kg")
#     axs[3].set_title("Integrated mass in kg")
#     axs[3].legend()
    
    
#     axs[4].plot(data[:,0], data[:,4], label = "GT Mass kg")
#     axs[4].set_xlabel("Time in seconds")
#     axs[4].set_ylabel("Mass in kg")
#     axs[4].set_title("Ground truth mass in kg")
#     axs[4].legend()
    
    
    
    st.set_y(0.95)
    fig.subplots_adjust(top=0.85)

    plt.show()

# %%
def plot_csv(file_path,del_t):
    mass_error = []
    time_delay = []
    time_delay.append(del_t)
    print("Data from time delay of", del_t," s\n\n")
    s = str(del_t)

    header_names = ['Time', 'Actual flow Value' , 'Target Flow', 'Pressure', 'Mass', 'Ground Truth Mass','Desired Mass', 'Set Voltage']
    df = pd.read_csv(file_path, names = header_names)
    mass_temp = plot_data(df)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_delt_014.csv"

plot_csv(file_path_name, 0.014)
# Out:
# Data from time delay of 0.014  s

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_delt_014_control_offset.csv"

plot_csv(file_path_name, 0.014)

# %%
header_names = ['Time', 'Actual flow Value' , 'Target Flow' 'Pressure', 'Mass', 'Ground Truth Mass','Desired Mass']
df = pd.read_csv(file_path_name, names = header_names)
data = df.to_numpy()
mass_max = np.max(data[:,3])
mass_max_gt = np.max(data[:,4])
offset = abs(mass_max - mass_max_gt)
corrected_integerated_mass = data[:,3] + offset

# %%
plt.plot(data[:,0], data[:,4], label = "Ground truth mass Value in kg")
plt.plot(data[:,0], corrected_integerated_mass,label = "Corrected integrated mass in kg")
plt.xlabel("Time in seconds")
plt.ylabel("Mass in kg")
plt.title("Ground truth vs Corrected integrated mass in kg")
plt.legend()
plt.show()

# %%
print(data.shape)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_delt_0005.csv"

plot_csv(file_path_name, 0.0005)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_delt_0005_kp_15.csv"

plot_csv(file_path_name, 0.0005)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_delt_0005_kp_15_kd_07.csv"

plot_csv(file_path_name, 0.0005)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_delt_0005_kp_025_kd_0.csv"

plot_csv(file_path_name, 0.0005)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_delt_0005_kp_035_kd_0.csv"

plot_csv(file_path_name, 0.0005)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_delt_0005_kp_045_kd_0.csv"

plot_csv(file_path_name, 0.0005)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_delt_0005_kp_045_kd_025.csv"

plot_csv(file_path_name, 0.0005)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_delt_0005_kp_040_kd_025.csv"

plot_csv(file_path_name, 0.0005)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_delt_0005_kp_050_kd_025.csv"

plot_csv(file_path_name, 0.0005)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_delt_0005_kp_037_kd_025.csv"

plot_csv(file_path_name, 0.0005)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_delt_0005_kp_035_kd_025.csv"

plot_csv(file_path_name, 0.0005)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_delt_0005_kp_035_kd_015.csv"

plot_csv(file_path_name, 0.0005)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_delt_0005_kp_035_kd_010.csv"

plot_csv(file_path_name, 0.0005)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_delt_0005_kp_032_kd_010.csv"

plot_csv(file_path_name, 0.0005)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_delt_0005_kp_032_kd_0.csv"

plot_csv(file_path_name, 0.0005)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_delt_0005_kp_032_kd_0.csv"

plot_csv(file_path_name, 0.0005)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_delt_0005_kp_032_kd_010.csv"

plot_csv(file_path_name, 0.0005)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_delt_0005_kp_033_kd_005.csv"

plot_csv(file_path_name, 0.0005)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_delt_0005_kp_033_kd_004.csv"

plot_csv(file_path_name, 0.0005)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_delt_0005_kp_033_kd_003.csv"

plot_csv(file_path_name, 0.0005)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_delt_0005_kp_033_kd_002.csv"

plot_csv(file_path_name, 0.0005)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_delt_0005_kp_033_kd_0025.csv"

plot_csv(file_path_name, 0.0005)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_delt_0005_kp_030_kd_0025.csv"

plot_csv(file_path_name, 0.0005)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_delt_0005_kp_030_kd_0025_time_mod.csv"

plot_csv(file_path_name, 0.0005)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_delt_0014_kp_030_kd_0025_time_mod.csv"

plot_csv(file_path_name, 0.0014)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_delt_0014_kp_065_kd_0025_time_mod.csv"

plot_csv(file_path_name, 0.0014)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_delt_0014_kp_065_kd_25_time_mod.csv"

plot_csv(file_path_name, 0.0014)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_delt_0014_kp_030_kd_25_time_mod.csv"

plot_csv(file_path_name, 0.0014)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_delt_0014_kp_025_kd_0025_time_mod.csv"

plot_csv(file_path_name, 0.0014)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_delt_0014_kp_025_kd_0015_time_mod.csv"

plot_csv(file_path_name, 0.0014)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_delt_0014_kp_025_kd_0015_ki_0007.csv"

plot_csv(file_path_name, 0.00005)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_delt_0014_kp_025_kd_0019_ki_0007.csv"

plot_csv(file_path_name, 0.00005)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_delt_0014_kp_032_kd_0019_ki_0007.csv"

plot_csv(file_path_name, 0.00005)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_7s_delt_00005_kp_032_kd_0019_ki_0007.csv"

plot_csv(file_path_name, 0.00005)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation//Inflating_finger_data_7s_delt_00005_kp_032_kd_001_ki_0007.csv"

plot_csv(file_path_name, 0.00005)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation//Inflating_finger_data_2s_delt_00005_kp_032_kd_001_ki_0007.csv"

plot_csv(file_path_name, 0.00005)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_2s_delt_014_kp_032_kd_001_ki_0007.csv"

plot_csv(file_path_name, 0.00005)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_7s_delt_014_kp_032_kd_001_ki_0007.csv"

plot_csv(file_path_name, 0.00005)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_7s_delt_014_kp_032_kd_001_ki_0007_set_voltage_offset.csv"

plot_csv(file_path_name, 0.00005)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_7s_delt_014_kp_032_kd_016_ki_0007_set_voltage_offset.csv"

plot_csv(file_path_name, 0.014)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_7s_delt_014_kp_032_kd_016_ki_0007_set_voltage_offset_corrected.csv"

plot_csv(file_path_name, 0.014)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_7s_delt_005_kp_032_kd_016_ki_0007_set_voltage_offset_corrected.csv"

plot_csv(file_path_name, 0.005)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_7s_delt_005_kp_032_kd_001_ki_0007_set_voltage_offset_corrected.csv"

plot_csv(file_path_name, 0.005)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_7s_delt_005_kp_032_kd_006_ki_0007_set_voltage_offset_corrected.csv"

plot_csv(file_path_name, 0.005)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_7s_delt_005_kp_032_kd_006_ki_0007_set_voltage_offset_corrected_2.45.csv"

plot_csv(file_path_name, 0.005)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_7s_delt_005_kp_035_kd_001_ki_0007_set_voltage_offset_corrected_2.45.csv"

plot_csv(file_path_name, 0.005)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_7s_delt_005_kp_035_kd_00_ki_0007_set_voltage_offset_corrected_2.45.csv"

plot_csv(file_path_name, 0.005)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_7s_delt_014_kp_045_kd_00_ki_0007_set_voltage_offset_corrected_2.45.csv"

plot_csv(file_path_name, 0.014)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_7s_delt_014_kp_055_kd_00_ki_0007_set_voltage_offset_corrected_2.45.csv"

plot_csv(file_path_name, 0.014)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_7s_delt_014_kp_065_kd_00_ki_0007_set_voltage_offset_corrected_2.45.csv"

plot_csv(file_path_name, 0.014)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_7s_delt_014_kp_075_kd_00_ki_0007_set_voltage_offset_corrected_2.45.csv"

plot_csv(file_path_name, 0.014)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_7s_delt_014_kp_085_kd_00_ki_0007_set_voltage_offset_corrected_2.45.csv"

plot_csv(file_path_name, 0.014)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_7s_delt_014_kp_095_kd_00_ki_0007_set_voltage_offset_corrected_2.45.csv"

plot_csv(file_path_name, 0.014)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_7s_delt_014_kp_105_kd_00_ki_0007_set_voltage_offset_corrected_2.45.csv"

plot_csv(file_path_name, 0.014)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_7s_delt_014_kp_105_kd_32_ki_0007_set_voltage_offset_corrected_2.45.csv"

plot_csv(file_path_name, 0.014)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_7s_delt_014_kp_100_kd_32_ki_0007_set_voltage_offset_corrected_2.45.csv"

plot_csv(file_path_name, 0.014)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_7s_delt_014_kp_097_kd_00_ki_0007_set_voltage_offset_corrected_2.45.csv"

plot_csv(file_path_name, 0.014)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_7s_delt_014_kp_097_kd_62_ki_0007_set_voltage_offset_corrected_2.45.csv"

plot_csv(file_path_name, 0.014)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_7s_delt_014_kp_097_kd_2_00_ki_0007_set_voltage_offset_corrected_2.45.csv"

plot_csv(file_path_name, 0.014)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_7s_delt_014_kp_107_kd_2_00_ki_0007_set_voltage_offset_corrected_2.45.csv"

plot_csv(file_path_name, 0.014)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_7s_delt_014_kp_107_kd_10_00_ki_0007_set_voltage_offset_corrected_2.45.csv"

plot_csv(file_path_name, 0.014)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_7s_delt_014_kp_099_kd_1_5_00_ki_0007_set_voltage_offset_corrected_2.45.csv"

plot_csv(file_path_name, 0.014)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_7s_delt_014_kp_097_kd_2_00_ki_0007_set_voltage_offset_corrected_2.45.csv"

plot_csv(file_path_name, 0.014)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_7s_delt_014_kp_097_kd_10_00_ki_0007_set_voltage_offset_corrected_2.45.csv"

plot_csv(file_path_name, 0.014)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_7s_delt_014_kp_097_kd_00_ki_0007_set_voltage_offset_corrected_2.45.csv"

plot_csv(file_path_name, 0.014)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_7s_delt_014_kp_095_kd_00_ki_0007_set_voltage_offset_corrected_2.45.csv"

plot_csv(file_path_name, 0.014)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_7s_delt_014_kp_095_kd_2_00_ki_0007_set_voltage_offset_corrected_2.45.csv"

plot_csv(file_path_name, 0.014)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_7s_delt_014_kp_095_kd_000_ki_0007_set_voltage_offset_corrected_2.45.csv"

plot_csv(file_path_name, 0.014)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_7s_delt_014_kp_095_kd_000_ki_0007_set_voltage_offset_corrected_2.4_5.csv"

plot_csv(file_path_name, 0.014)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_7s_delt_014_kp_095_kd_000_ki_0007_set_voltage_offset_corrected_2.4_5.csv"

plot_csv(file_path_name, 0.014)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_1s_delt_014_kp_2_kd_000_ki_0007_set_voltage_offset_corrected_2.4_5.csv"

plot_csv(file_path_name, 0.014)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_1s_delt_014_kp_2_kd_000_ki_0007_set_voltage_offset_corrected_2.4_5.csv"

plot_csv(file_path_name, 0.014)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_1s_delt_014_kp_2_kd_000_ki_0007_set_voltage_offset_corrected_2.4_5.csv"

plot_csv(file_path_name, 0.014)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_1s_delt_014_kp_2_kd_000_ki_0007_set_voltage_offset_corrected_2.4_5.csv"

plot_csv(file_path_name, 0.014)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_finger_data_1s_delt_014_kp_2_kd_000_ki_0007_set_voltage_offset_corrected_2.4_5.csv"

plot_csv(file_path_name, 0.014)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_deflating_finger_data.csv"

plot_csv(file_path_name, 0.014)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_deflating_finger_data_def_kp0_070.csv"

plot_csv(file_path_name, 0.014)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_deflating_finger_data_def_kp0_050.csv"

plot_csv(file_path_name, 0.014)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_deflating_finger_data_def_kp0_070.csv"

plot_csv(file_path_name, 0.014)
# Out:
# Data from time delay of 0.014  s

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_deflating_finger_data_def_kp0_050_AD_DA_hat.csv"

plot_csv(file_path_name, 0.014)
# Out:
# Data from time delay of 0.014  s
