# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from datetime import date

# %%
def plot_data(df):   
    max_range = 200
    data = df.to_numpy()
    fig, axs = plt.subplots(5,1, figsize=(15,25))
    st = fig.suptitle("Data plotted on", fontsize="x-large")
    axs[0].plot(data[:,0],data[:,5]*1e6, label = "Ground truth mass mg")
    axs[0].plot(data[:,0],data[:,4]*1e6, label = "Integerated mass mg")
    axs[0].plot(data[:,0],data[:,-4]*1e6, label = "Desired Mass mg")    
    axs[0].set_xlabel("Time in seconds")
    axs[0].set_ylabel("Mass in mg")
    axs[0].set_title("Integrated mass vs Desired Mass")
    axs[0].grid()
    axs[0].legend()

    axs[1].plot(data[:,0],data[:,1], label = "Measured flow Value (l/min)")
    axs[1].plot(data[:,0],data[:,2], label = "Target flow Value(l/min)")
    axs[1].set_xlabel("Time in seconds")
    axs[1].set_ylabel("Volume flow rate in l/min")
    axs[1].set_title("Measured value of the flow rate")
    axs[1].grid()
    axs[1].legend()

    axs[2].plot(data[:,0],data[:,3], label = "Pressure in kPa")
    axs[2].set_xlabel("Time in seconds")
    axs[2].set_ylabel("Pressure in kPa")
    axs[2].set_title("Measured pressure")
    axs[2].grid()
    axs[2].legend()
    
    axs[3].plot(data[:,0],data[:,7], label = "Set Voltage Inflation in V")
    axs[3].plot(data[:,0],data[:,-1], label = "Set Voltage Deflation in V")
    axs[3].set_xlabel("Time in seconds")
    axs[3].set_ylabel("Set voltage in V")
    axs[3].set_title("Set Voltage")
    axs[3].grid()
    axs[3].legend()
    
    axs[4].plot(data[:,0],data[:,-2]*1000,  label = "Set Current")
    axs[4].set_xlabel("Time in seconds")
    axs[4].set_ylabel("Set Current in mA")
    axs[4].set_title("Set Current")
    axs[4].grid()
    axs[4].legend()
    
#     axs[3].plot(data[:,0], data[:,3], label = "Integrated Mass kg")
#     axs[3].set_xlabel("Time in seconds")
#     axs[3].set_ylabel("Mass in kg")
#     axs[3].set_title("Integrated mass in kg")
#     axs[3].legend()
    
    
#     axs[4].plot(data[:,0], data[:,4], label = "GT Mass kg")
#     axs[4].set_xlabel("Time in seconds")
#     axs[4].set_ylabel("Mass in kg")
#     axs[4].set_title("Ground truth mass in kg")
#     axs[4].legend()    
    
    st.set_y(0.95)
    fig.subplots_adjust(top=0.85)
    plt.show()

# %%
def plot_csv(file_path,del_t):
    mass_error = []
    time_delay = []
    time_delay.append(del_t)
    print("Data from time delay of", del_t," s\n\n")
    s = str(del_t)

    header_names = ['Time', 'Actual flow Value' , 'Target Flow', 'Pressure', 'Integerated Mass', 'Ground Truth Mass','Desired Mass', 'Set Voltage Inflation', 'Sense current', 'Set Voltage Deflation']
    df = pd.read_csv(file_path, names = header_names)
    mass_temp = plot_data(df)

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_deflating_finger_data_def_kp0_050_AD_DA_hat.csv"

plot_csv(file_path_name, 0.04)
# Out:
# Data from time delay of 0.04  s

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_deflating_finger_data_def_kp0_050_AD_DA_hat_linear.csv"

plot_csv(file_path_name, 0.04)
# Out:
# Data from time delay of 0.04  s

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_deflating_finger_data_def_kp0_050_AD_DA_hat_do.csv"

plot_csv(file_path_name, 0.04)
# Out:
# Data from time delay of 0.04  s

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_deflating_finger_data_def_kp0_050_AD_DA_hat_do_cyclic.csv"

plot_csv(file_path_name, 0.04)
# Out:
# Data from time delay of 0.04  s

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_deflating_finger_data_def_kp0_050_AD_DA_hat_do_cyclic.csv"

plot_csv(file_path_name, 0.04)
# Out:
# Data from time delay of 0.04  s

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_deflating_finger_data_def_kp0_050_AD_DA_hat_do_cyclic.csv"

plot_csv(file_path_name, 0.04)
# Out:
# Data from time delay of 0.04  s

# %%
print(a['b'])
# Out:
# 340

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_deflating_finger_data_def_kp0_050_AD_DA_hat_do_cyclic.csv"

plot_csv(file_path_name, 0.04)
# Out:
# Data from time delay of 0.04  s

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_deflating_finger_data_def_kp0_050_AD_DA_hat_do_cyclic.csv"

plot_csv(file_path_name, 0.04)
# Out:
# Data from time delay of 0.04  s

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_deflating_finger_data_def_kp0_050_AD_DA_hat_do_cyclic.csv"

plot_csv(file_path_name, 0.04)
# Out:
# Data from time delay of 0.04  s

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_deflating_finger_data_def_kp0_050_AD_DA_hat_do_cyclic.csv"

plot_csv(file_path_name, 0.04)
# Out:
# Data from time delay of 0.04  s

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_deflating_finger_data_def_kp0_050_AD_DA_hat_do_cyclic.csv"

plot_csv(file_path_name, 0.04)
# Out:
# Data from time delay of 0.04  s

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_deflating_finger_data_def_kp0_050_AD_DA_hat_do_cyclic.csv"

plot_csv(file_path_name, 0.04)
# Out:
# Data from time delay of 0.04  s

# %%
file_path_name = "./Data_from_PropValves/Kelly/Inflation/Inflating_deflating_finger_data_def_kp0_050_AD_DA_hat_do_cyclic.csv"

plot_csv(file_path_name, 0.04)
# Out:
# Data from time delay of 0.04  s
