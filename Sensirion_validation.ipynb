# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from datetime import date

# %%
def plot_data(df):   
    max_range = 200
    data = df.to_numpy()
    fig, axs = plt.subplots(5,1, sharex = True, figsize=(25,25))
    st = fig.suptitle("Data plotted on", fontsize="x-large")
    axs[0].plot(data[:,0], data[:,3]*1e6, label = "Integerated mass kg")
    axs[0].plot(data[:,0], data[:,4]*1e6, label = "GT Mass kg")
    axs[0].set_xlabel("Time in seconds")
    axs[0].set_ylabel("Mass in kg")
    axs[0].set_title("Integrated mass vs GT mass")
    axs[0].legend()

    axs[1].plot(data[:,0], data[:,1], label = "Measured Value(l/min)")
    axs[1].set_xlabel("Time in seconds")
    axs[1].set_ylabel("Volume flow rate in l/min")
    axs[1].set_title("Measured value of the flow rate")
    axs[1].legend()

    axs[2].plot(data[:,0], data[:,2], label = "Pressure in kPa")
    axs[2].set_xlabel("Time in seconds")
    axs[2].set_ylabel("Pressure in kPa")
    axs[2].set_title("Measured pressure")
    axs[2].legend()
    
    axs[3].plot(data[:,0], data[:,3], label = "Integrated Mass kg")
    axs[3].set_xlabel("Time in seconds")
    axs[3].set_ylabel("Mass in kg")
    axs[3].set_title("Integrated mass in kg")
    axs[3].legend()
    
    
    axs[4].plot(data[:,0], data[:,4], label = "GT Mass kg")
    axs[4].set_xlabel("Time in seconds")
    axs[4].set_ylabel("Mass in kg")
    axs[4].set_title("Ground truth mass in kg")
    axs[4].legend()
    
    
    
    st.set_y(0.95)
    fig.subplots_adjust(top=0.85)

    plt.show()

# %%
def plot_csv(file_path, del_t):
#     mass_error = []
#     time_delay = []
#     time_delay.append(del_t)
    print("Data from time delay of", del_t," s\n\n")
#     print("Target flow: " + str(target_flow)+" l/min")
#     print("Proportional Gain: ", kp)
#     print("Deivative Gain: ", kd)
#     print("Integral Gain: ", ki)
#     s = str(del_t)

    header_names = ['Time', 'Actual Flow Value' , 'Pressure Value', 'Current mass', 'Current GT Mass' ]
    df = pd.read_csv(file_path, names = header_names)
    plot_data(df)

# %%
file_path_name = "./Data_from_PropValves/Sensirion/Validation/Validate_sensirion.csv"

plot_csv(file_path_name, 0.005)
# Out:
# Data from time delay of 0.005  s

# %%
a = 4.748438756084631e-05/(287.058 * 293.15)
print(a)
# Out:
# 5.642756214842493e-10

# %%
file_path_name = "./Data_from_PropValves/Sensirion/Validation/Validate_sensirion_delt_004.csv"

plot_csv(file_path_name, 0.004)
# Out:
# Data from time delay of 0.004  s

# %%
file_path_name = "./Data_from_PropValves/Sensirion/Validation/Validate_sensirion_delt_001.csv"

plot_csv(file_path_name, 0.001)
# Out:
# Data from time delay of 0.004  s

# %%
file_path_name = "./Data_from_PropValves/Sensirion/Validation/Validate_sensirion_delt_001_.csv"

plot_csv(file_path_name, 0.001)
# Out:
# Data from time delay of 0.001  s

# %%
file_path_name = "./Data_from_PropValves/Sensirion/Validation/Validate_sensirion_delt_0005.csv"

plot_csv(file_path_name, 0.0005)
# Out:
# Data from time delay of 0.0005  s

# %%
file_path_name = "./Data_from_PropValves/Sensirion/Validation/Validate_sensirion_delt_01.csv"

plot_csv(file_path_name, 0.01)
# Out:
# Data from time delay of 0.01  s

# %%
file_path_name = "./Data_from_PropValves/Sensirion/Validation/Validate_sensirion_delt_001.csv"

plot_csv(file_path_name, 0.001)
# Out:
# Data from time delay of 0.01  s

# %%
file_path_name = "./Data_from_PropValves/Sensirion/Validation/Validate_sensirion_delt_005.csv"

plot_csv(file_path_name, 0.005)
# Out:
# Data from time delay of 0.005  s

# %%
file_path_name = "./Data_from_PropValves/Sensirion/Validation/Validate_sensirion_delt_005_time_offset.csv"

plot_csv(file_path_name, 0.005)
# Out:
# Data from time delay of 0.005  s

# %%
file_path_name = "./Data_from_PropValves/Sensirion/Validation/Validate_sensirion_delt_01_time_offset.csv"

plot_csv(file_path_name, 0.01)
# Out:
# Data from time delay of 0.01  s

# %%
header_names = ['Time', 'Actual Flow Value' , 'Pressure Value', 'Current mass', 'Current GT Mass' ]

df = pd.read_csv(file_path_name, names = header_names)
data = df.to_numpy()
mass_max = np.max(data[:,3])
mass_max_gt = np.max(data[:,4])
offset = abs(mass_max - mass_max_gt)
corrected_integerated_mass = data[:,3] + offset

# %%
plt.plot(data[:,0], data[:,4], label = "Ground truth mass Value in kg")
plt.plot(data[:,0], corrected_integerated_mass,label = "Corrected integrated mass in kg")
plt.xlabel("Time in seconds")
plt.ylabel("Mass in kg")
plt.title("Ground truth vs Corrected integrated mass in kg")
plt.legend()
plt.show()

# %%
file_path_name = "./Data_from_PropValves/Sensirion/Validation/Validate_sensirion_delt_02_time_offset.csv"

plot_csv(file_path_name, 0.02)
# Out:
# Data from time delay of 0.02  s

# %%
header_names = ['Time', 'Actual Flow Value' , 'Pressure Value', 'Current mass', 'Current GT Mass' ]

df = pd.read_csv(file_path_name, names = header_names)
data = df.to_numpy()
mass_max = np.max(data[:,3])
mass_max_gt = np.max(data[:,4])
offset = abs(mass_max - mass_max_gt)
corrected_integerated_mass = data[:,3] + offset

plt.plot(data[:,0], data[:,4], label = "Ground truth mass Value in kg")
plt.plot(data[:,0], corrected_integerated_mass,label = "Corrected integrated mass in kg")
plt.xlabel("Time in seconds")
plt.ylabel("Mass in kg")
plt.title("Ground truth vs Corrected integrated mass in kg")
plt.legend()
plt.show()

# %%
file_path_name = "./Data_from_PropValves/Sensirion/Validation/Validate_sensirion_delt_014_time_offset.csv"

plot_csv(file_path_name, 0.014)
# Out:
# Data from time delay of 0.014  s

# %%
file_path_name = "./Data_from_PropValves/Sensirion/Validation/Validate_sensirion_delt_01_time_offset_.csv"

plot_csv(file_path_name, 0.01)
# Out:
# Data from time delay of 0.01  s

# %%
file_path_name = "./Data_from_PropValves/Sensirion/Validation/Validate_sensirion_delt_014_time_offset_.csv"

plot_csv(file_path_name, 0.014)
# Out:
# Data from time delay of 0.014  s

# %%
file_path_name = "./Data_from_PropValves/Sensirion/Validation/Validate_sensirion_delt_014_time_offset1.csv"

plot_csv(file_path_name, 0.014)
# Out:
# Data from time delay of 0.014  s

# %%
file_path_name = "./Data_from_PropValves/Sensirion/Validation/Validate_sensirion_delt_014_time_offset2.csv"

plot_csv(file_path_name, 0.014)
# Out:
# Data from time delay of 0.014  s

# %%
file_path_name = "./Data_from_PropValves/Sensirion/Validation/Validate_sensirion_delt_014_time_offset3.csv"

plot_csv(file_path_name, 0.014)
# Out:
# Data from time delay of 0.014  s
